# %% [markdown]
# <a href="https://colab.research.google.com/github/zubaeteee20210205109-droid/Trial/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

DATASET_PATH = "/content/drive/MyDrive/ArsenicSkinImage(BD)"

for root, dirs, files in os.walk(DATASET_PATH):
    level = root.replace(DATASET_PATH, '').count(os.sep)
    indent = ' ' * 4 * level
    print(f"{indent}{os.path.basename(root)}/")
    subindent = ' ' * 4 * (level + 1)

    image_count = len([
        f for f in files
        if f.lower().endswith(
            ('.jpg','.jpeg','.png','.bmp','.webp')
        )
    ])

    if image_count > 0:
        print(f"{subindent}Images: {image_count}")
# Out:
# ArsenicSkinImage(BD)/
#     Augmented/
#         infected/
#             Images: 4446
#         not_infected/
#             Images: 4446
#     Original/
#         infacted/
#             Images: 741
#         not_infacted/
#             Images: 546

# %%
import os

infected_path = "/content/drive/MyDrive/ArsenicSkinImage(BD)/Augmented/infected"

files = os.listdir(infected_path)

print(files[:20])
# Out:
# ['IMG_1736_augmented_2.png', 'IMG_1735_augmented_2.png', 'IMG_1726_augmented_1.png', 'IMG_1741_augmented_2.png', 'IMG_1731_augmented_5.png', 'IMG_1747_augmented_6.png', 'IMG_1743_augmented_3.png', 'IMG_1727_augmented_5.png', 'IMG_1746_augmented_1.png', 'IMG_1724_augmented_1.png', 'IMG_1778_augmented_4.png', 'IMG_1761_augmented_5.png', 'IMG_1753_augmented_2.png', 'IMG_1770_augmented_6.png', 'IMG_1765_augmented_5.png', 'IMG_1774_augmented_2.png', 'IMG_1771_augmented_5.png', 'IMG_1777_augmented_1.png', 'IMG_1749_augmented_3.png', 'IMG_1756_augmented_3.png']

# %%
import os

infected_path = "/content/drive/MyDrive/ArsenicSkinImage(BD)/Augmented/infected"

original_groups = set()

for file in os.listdir(infected_path):

    original_id = "_".join(file.split("_")[:2])

    original_groups.add(original_id)

print("Total infected images :", len(os.listdir(infected_path)))
print("Unique original infected images :", len(original_groups))
# Out:
# Total infected images : 4446
# Unique original infected images : 741

# %%
import os

path = "/content/drive/MyDrive/ArsenicSkinImage(BD)/Augmented/not_infected"

groups = set()

for file in os.listdir(path):
    original_id = "_".join(file.split("_")[:2])
    groups.add(original_id)

print("Total non_infected images :", len(os.listdir(path)))
print("Unique original non_infected images :", len(groups))
# Out:
# Total non_infected images : 4446
# Unique original non_infected images : 702

# %%
import os

infected_path = "/content/drive/MyDrive/ArsenicSkinImage(BD)/Augmented/infected"

files = sorted(os.listdir(infected_path))

for f in files[:30]:
    print(f)
# Out:
# IMG_1169_augmented_1.png
# IMG_1169_augmented_2.png
# IMG_1169_augmented_3.png
# IMG_1169_augmented_4.png
# IMG_1169_augmented_5.png
# IMG_1169_augmented_6.png
# IMG_1170_augmented_1.png
# IMG_1170_augmented_2.png
# IMG_1170_augmented_3.png
# IMG_1170_augmented_4.png
# IMG_1170_augmented_5.png
# IMG_1170_augmented_6.png
# IMG_1171_augmented_1.png
# IMG_1171_augmented_2.png
# IMG_1171_augmented_3.png
# IMG_1171_augmented_4.png
# IMG_1171_augmented_5.png
# IMG_1171_augmented_6.png
# IMG_1172_augmented_1.png
# IMG_1172_augmented_2.png
# IMG_1172_augmented_3.png
# IMG_1172_augmented_4.png
# IMG_1172_augmented_5.png
# IMG_1172_augmented_6.png
# IMG_1173_augmented_1.png
# IMG_1173_augmented_2.png
# IMG_1173_augmented_3.png
# IMG_1173_augmented_4.png
# IMG_1173_augmented_5.png
# IMG_1173_augmented_6.png

# %%
import os

infected_path = "/content/drive/MyDrive/ArsenicSkinImage(BD)/Augmented/infected"
non_path = "/content/drive/MyDrive/ArsenicSkinImage(BD)/Augmented/not_infected"

print("Infected examples:")
for f in sorted(os.listdir(infected_path))[:20]:
    print(f)

print("\nNon infected examples:")
for f in sorted(os.listdir(non_path))[:20]:
    print(f)
# Out:
# Infected examples:
# IMG_1169_augmented_1.png
# IMG_1169_augmented_2.png
# IMG_1169_augmented_3.png
# IMG_1169_augmented_4.png
# IMG_1169_augmented_5.png
# IMG_1169_augmented_6.png
# IMG_1170_augmented_1.png
# IMG_1170_augmented_2.png
# IMG_1170_augmented_3.png
# IMG_1170_augmented_4.png
# IMG_1170_augmented_5.png
# IMG_1170_augmented_6.png
# IMG_1171_augmented_1.png
# IMG_1171_augmented_2.png
# IMG_1171_augmented_3.png
# IMG_1171_augmented_4.png
# IMG_1171_augmented_5.png
# IMG_1171_augmented_6.png
# IMG_1172_augmented_1.png
# IMG_1172_augmented_2.png
#
# Non infected examples:
# 363716792_1228863924467938_7273903535216054924_n_augmented_1.png
# 363716792_1228863924467938_7273903535216054924_n_augmented_2.png
# 363716792_1228863924467938_7273903535216054924_n_augmented_3.png
# 363716792_1228863924467938_7273903535216054924_n_augmented_4.png
# 363716792_1228863924467938_7273903535216054924_n_augmented_5.png
# 363716792_1228863924467938_7273903535216054924_n_augmented_6.png
# ...

# %%
import matplotlib.pyplot as plt
import cv2
import os

folder = "/content/drive/MyDrive/ArsenicSkinImage(BD)/Augmented/infected"

images = [
    "IMG_1170_augmented_1.png",
    "IMG_1170_augmented_2.png",
    "IMG_1170_augmented_3.png",
    "IMG_1170_augmented_4.png",
    "IMG_1170_augmented_5.png",
    "IMG_1170_augmented_6.png"
]

plt.figure(figsize=(18,8))

for i, img_name in enumerate(images):
    img = cv2.imread(os.path.join(folder, img_name))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.subplot(2,3,i+1)
    plt.imshow(img)
    plt.title(img_name.split("_")[-1])
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import os

infected_path = "/content/drive/MyDrive/ArsenicSkinImage(BD)/Augmented/infected"
not_infected_path = "/content/drive/MyDrive/ArsenicSkinImage(BD)/Augmented/not_infected"

print("Infected last examples:")
print(sorted(os.listdir(infected_path))[-10:])

print("\nNot infected last examples:")
print(sorted(os.listdir(not_infected_path))[-10:])
# Out:
# Infected last examples:
# ['IMG_1912_augmented_3.png', 'IMG_1912_augmented_4.png', 'IMG_1912_augmented_5.png', 'IMG_1912_augmented_6.png', 'IMG_1913_augmented_1.png', 'IMG_1913_augmented_2.png', 'IMG_1913_augmented_3.png', 'IMG_1913_augmented_4.png', 'IMG_1913_augmented_5.png', 'IMG_1913_augmented_6.png']
#
# Not infected last examples:
# ['IMG_3428_augmented_3.png', 'IMG_3428_augmented_4.png', 'IMG_3428_augmented_5.png', 'IMG_3428_augmented_6.png', 'IMG_3430_augmented_1.png', 'IMG_3430_augmented_2.png', 'IMG_3430_augmented_3.png', 'IMG_3430_augmented_4.png', 'IMG_3430_augmented_5.png', 'IMG_3430_augmented_6.png']

# %%
import os
from collections import Counter

DATASET_PATH = "/content/drive/MyDrive/ArsenicSkinImage(BD)/Augmented"

groups = []

for cls in ["infected", "not_infected"]:

    folder = os.path.join(DATASET_PATH, cls)

    for file in os.listdir(folder):

        if file.endswith(".png"):
            group_id = file.split("_augmented_")[0]
            groups.append(group_id)

counter = Counter(groups)

print("Minimum augmentations :", min(counter.values()))
print("Maximum augmentations :", max(counter.values()))

print("\nDistribution:")
print(Counter(counter.values()))
# Out:
# Minimum augmentations : 6
# Maximum augmentations : 6
#
# Distribution:
# Counter({6: 1482})

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input

from sklearn.model_selection import GroupKFold
from sklearn.utils.class_weight import compute_class_weight

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    auc,
    precision_recall_curve,
    average_precision_score
)

from sklearn.calibration import calibration_curve

# %%
DATASET_PATH = "/content/drive/MyDrive/ArsenicSkinImage(BD)/Augmented"

IMG_SIZE = (224,224)
BATCH_SIZE = 32
N_SPLITS = 5

# %%
data = []

for label in ["infected", "not_infected"]:

    folder = os.path.join(DATASET_PATH, label)

    for file in os.listdir(folder):

        if file.endswith(".png"):

            filepath = os.path.join(folder, file)

            group_id = file.split("_augmented_")[0]

            data.append(
                [filepath, label, group_id]
            )

df = pd.DataFrame(
    data,
    columns=[
        "filepath",
        "label",
        "group"
    ]
)

print("Total Images:", len(df))
print("Unique Groups:", df["group"].nunique())
# Out:
# Total Images: 8892
# Unique Groups: 1482

# %%
def transformer_block(x):

    attn = layers.MultiHeadAttention(
        num_heads=4,
        key_dim=x.shape[-1] // 4
    )(x, x)

    x1 = layers.Add()([x, attn])

    x1 = layers.LayerNormalization()(x1)

    ffn = layers.Dense(
        x.shape[-1] * 2,
        activation='gelu'
    )(x1)

    ffn = layers.Dense(
        x.shape[-1]
    )(ffn)

    x2 = layers.Add()([x1, ffn])

    x2 = layers.LayerNormalization()(x2)

    return x2

# %%
def build_model():

    inputs = layers.Input(
        shape=(224,224,3)
    )

    base = tf.keras.applications.EfficientNetV2B0(
        include_top=False,
        weights='imagenet',
        input_tensor=inputs
    )

    base.trainable = True

    for layer in base.layers[:-20]:
        layer.trainable = False

    x = base.output

    h,w,c = x.shape[1],x.shape[2],x.shape[3]

    patches = h*w

    x = layers.Reshape(
        (patches,c)
    )(x)

    pos = tf.range(
        start=0,
        limit=patches,
        delta=1
    )

    pos_emb = layers.Embedding(
        patches,
        c
    )(pos)

    x = x + pos_emb

    x = transformer_block(x)

    x = transformer_block(x)

    x = layers.GlobalAveragePooling1D()(x)

    x = layers.Dense(
        512,
        activation='relu'
    )(x)

    x = layers.Dropout(
        0.4
    )(x)

    x = layers.Dense(
        256,
        activation='relu'
    )(x)

    x = layers.Dropout(
        0.3
    )(x)

    outputs = layers.Dense(
        2,
        activation='softmax'
    )(x)

    model = models.Model(
        inputs,
        outputs
    )

    return model

# %%
mean_fpr = np.linspace(
    0,
    1,
    100
)

tprs = []

aucs = []

fold_accuracies = []

gkf = GroupKFold(
    n_splits=N_SPLITS
)

# %%
for fold, (train_idx, val_idx) in enumerate(
    gkf.split(
        df,
        df["label"],
        groups=df["group"]
    ),
    start=1
):

    print("\n" + "="*50)
    print(f"Fold {fold}")
    print("="*50)

    train_df = df.iloc[train_idx]
    val_df = df.iloc[val_idx]
# Out:
# ...
# Fold 1
# ...
#
# ...
# Fold 2
# ...
#
# ...
# Fold 3
# ...
#
# ...
# Fold 4
# ...
#
# ...
# Fold 5
# ...

# %%
    train_datagen = ImageDataGenerator(
        preprocessing_function=preprocess_input,
        rotation_range=40,
        zoom_range=0.3,
        horizontal_flip=True,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2
    )

    val_datagen = ImageDataGenerator(
        preprocessing_function=preprocess_input
    )

# %%
    train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        x_col="filepath",
        y_col="label",
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode="categorical",
        shuffle=True
    )

    val_generator = val_datagen.flow_from_dataframe(
        dataframe=val_df,
        x_col="filepath",
        y_col="label",
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode="categorical",
        shuffle=False
    )
# Out:
# Found 7116 validated image filenames belonging to 2 classes.
# Found 1776 validated image filenames belonging to 2 classes.

# %%
    labels = train_generator.classes

    class_weights = compute_class_weight(
        class_weight="balanced",
        classes=np.unique(labels),
        y=labels
    )

    class_weights = dict(
        enumerate(class_weights)
    )

# %%
    model = build_model()
# Out:
# ...
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
    model.compile(
        optimizer=tf.keras.optimizers.AdamW(
            learning_rate=3e-4,
            weight_decay=1e-4
        ),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

# %%
    callbacks_list = [

        callbacks.ModelCheckpoint(
            f"best_fold_{fold}.keras",
            monitor="val_accuracy",
            save_best_only=True,
            verbose=1
        ),

        callbacks.EarlyStopping(
            monitor="val_loss",
            patience=5,
            restore_best_weights=True
        ),

        callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=3,
            min_lr=1e-6,
            verbose=1
        )
    ]

# %%
    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=10,
        class_weight=class_weights,
        callbacks=callbacks_list
    )
# Out:
# Epoch 1/10
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - accuracy: 0.8136 - loss: 0.4735
# Epoch 1: val_accuracy improved from None to 0.96171, saving model to best_fold_5.keras
#
# Epoch 1: finished saving model to best_fold_5.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 4052s 18s/step - accuracy: 0.8863 - loss: 0.3119 - val_accuracy: 0.9617 - val_loss: 0.1114 - learning_rate: 3.0000e-04
# Epoch 2/10
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - accuracy: 0.9582 - loss: 0.1238
# Epoch 2: val_accuracy did not improve from 0.96171
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 3789s 17s/step - accuracy: 0.9591 - loss: 0.1232 - val_accuracy: 0.9578 - val_loss: 0.1309 - learning_rate: 3.0000e-04
# Epoch 3/10
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - accuracy: 0.9704 - loss: 0.1026
# Epoch 3: val_accuracy improved from 0.96171 to 0.97297, saving model to best_fold_5.keras
#
# Epoch 3: finished saving model to best_fold_5.keras
# ...

# %%
for fold, (train_idx, val_idx) in enumerate(
    gkf.split(
        df,
        df["label"],
        groups=df["group"]
    ),
    start=1
):

    print(f"Starting Fold {fold}")
# Out:
# Starting Fold 1
# Starting Fold 2
# Starting Fold 3
# Starting Fold 4
# Starting Fold 5

# %%
fold_accuracies = []

for fold, (train_idx, val_idx) in enumerate(
    gkf.split(
        df,
        df["label"],
        groups=df["group"]
    ),
    start=1
):

    ...

    loss, accuracy = model.evaluate(
        val_generator,
        verbose=0
    )

    fold_accuracies.append(
        accuracy * 100
    )

    print(fold_accuracies)
# Out:
# [97.52252101898193]
# [97.52252101898193, 97.52252101898193]
# [97.52252101898193, 97.52252101898193, 97.52252101898193]
# [97.52252101898193, 97.52252101898193, 97.52252101898193, 97.52252101898193]
# [97.52252101898193, 97.52252101898193, 97.52252101898193, 97.52252101898193, 97.52252101898193]

# %%
print("\n")
print("="*50)
print("Cross Validation Results")
print("="*50)

for i, score in enumerate(
    fold_accuracies,
    start=1
):
    print(
        f"Fold {i}: {score:.2f}%"
    )

print(
    "\nFinal_accuracy:",
    np.mean(fold_accuracies)
)

print(
    "Standard Deviation:",
    np.std(fold_accuracies)
)
# Out:
# ...
# Cross Validation Results
# ...
# Fold 1: 97.52%
# Fold 2: 97.52%
# Fold 3: 97.52%
# Fold 4: 97.52%
# Fold 5: 97.52%
#
# Final_accuracy: 97.52252101898193
# Standard Deviation: 0.0

# %%
final_accuracy = np.mean(fold_accuracies)
final_std = np.std(fold_accuracies)

print(
    f"Final Accuracy = {final_accuracy:.2f}% ± {final_std:.2f}%"
)
# Out:
# Final Accuracy = 97.52% ± 0.00%

# %%
plt.bar(
    range(1, len(fold_accuracies)+1),
    fold_accuracies
)

for i, v in enumerate(fold_accuracies):
    plt.text(
        i+1,
        v,
        f'{v:.2f}%',
        ha='center'
    )

plt.xticks(
    range(1, len(fold_accuracies)+1)
)

plt.title(
    f'Mean={np.mean(fold_accuracies):.2f}% ± {np.std(fold_accuracies):.2f}'
)

plt.xlabel('Fold')
plt.ylabel('Accuracy (%)')

plt.show()

# %%
plt.figure(figsize=(14,5))

plt.subplot(1,2,1)

plt.plot(
    history.history['accuracy'],
    label='Training Accuracy'
)

plt.plot(
    history.history['val_accuracy'],
    label='Validation Accuracy'
)

plt.title(
    'Training and Validation Accuracy'
)

plt.xlabel(
    'Epoch'
)

plt.ylabel(
    'Accuracy'
)

plt.legend()

plt.subplot(1,2,2)

plt.plot(
    history.history['loss'],
    label='Training Loss'
)

plt.plot(
    history.history['val_loss'],
    label='Validation Loss'
)

plt.title(
    'Training and Validation Loss'
)

plt.xlabel(
    'Epoch'
)

plt.ylabel(
    'Loss'
)

plt.legend()

plt.tight_layout()

plt.show()

# %%
y_pred_prob = model.predict(
    val_generator
)

y_pred = np.argmax(
    y_pred_prob,
    axis=1
)

y_true = val_generator.classes

class_names = list(
    val_generator.class_indices.keys()
)
# Out:
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 278s 5s/step

# %%
cm = confusion_matrix(
    y_true,
    y_pred
)

plt.figure(figsize=(7,6))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")

plt.show()

# %%
fpr, tpr, _ = roc_curve(
    y_true,
    y_pred_prob[:,1]
)

roc_auc = auc(
    fpr,
    tpr
)

# Store ROC values for Mean ROC calculation
interp_tpr = np.interp(
    mean_fpr,
    fpr,
    tpr
)

interp_tpr[0] = 0.0

tprs.append(
    interp_tpr
)

aucs.append(
    roc_auc
)

# Individual Fold ROC Curve
plt.figure(figsize=(7,6))

plt.plot(
    fpr,
    tpr,
    linewidth=2,
    label=f'Fold {fold} AUC = {roc_auc:.4f}'
)

plt.plot(
    [0,1],
    [0,1],
    linestyle='--'
)

plt.xlabel(
    'False Positive Rate'
)

plt.ylabel(
    'True Positive Rate'
)

plt.title(
    f'Fold {fold} ROC Curve'
)

plt.legend(
    loc='lower right'
)

plt.grid(True)

plt.tight_layout()

plt.show()

# %%
mean_tpr = np.mean(
    tprs,
    axis=0
)

mean_tpr[-1] = 1.0

mean_auc = auc(
    mean_fpr,
    mean_tpr
)

std_auc = np.std(
    aucs
)

plt.figure(figsize=(7,6))

plt.plot(
    mean_fpr,
    mean_tpr,
    label=f"Mean ROC (AUC={mean_auc:.4f} ± {std_auc:.4f})"
)

plt.plot(
    [0,1],
    [0,1],
    linestyle='--'
)

plt.xlabel(
    "False Positive Rate"
)

plt.ylabel(
    "True Positive Rate"
)

plt.title(
    "Mean ROC Across Folds"
)

plt.legend()

plt.grid(True)

plt.tight_layout()

plt.show()

# %%
precision_curve, recall_curve, _ = precision_recall_curve(
    y_true,
    y_pred_prob[:,1]
)

ap = average_precision_score(
    y_true,
    y_pred_prob[:,1]
)

plt.figure(figsize=(7,6))

plt.plot(
    recall_curve,
    precision_curve,
    linewidth=2,
    label=f'AP = {ap:.4f}'
)

plt.xlabel(
    'Recall'
)

plt.ylabel(
    'Precision'
)

plt.title(
    'Precision Recall Curve'
)

plt.legend()

plt.grid(True)

plt.show()

# %%
confidence = np.max(
    y_pred_prob,
    axis=1
)

plt.figure(figsize=(7,5))

sns.histplot(
    confidence,
    bins=20,
    kde=True
)

plt.xlabel(
    'Prediction Confidence'
)

plt.ylabel(
    'Number of Samples'
)

plt.title(
    'Prediction Confidence Distribution'
)

plt.tight_layout()

plt.show()

# %%
metrics_names = ["Precision","Recall","F1 Score"]

metrics_values = [
    precision_score(y_true,y_pred,average='weighted')*100,
    recall_score(y_true,y_pred,average='weighted')*100,
    f1_score(y_true,y_pred,average='weighted')*100
]

bars = plt.bar(metrics_names, metrics_values)

for bar in bars:
    plt.text(
        bar.get_x()+bar.get_width()/2,
        bar.get_height(),
        f'{bar.get_height():.2f}%',
        ha='center'
    )

plt.title("Performance Metrics Comparison")
plt.ylabel("Percentage (%)")
plt.ylim(0,105)
plt.show()

# %%
print(
    classification_report(
        y_true,
        y_pred,
        target_names=class_names
    )
)
# Out:
#               precision    recall  f1-score   support
#
#     infected       1.00      0.95      0.97       888
# not_infected       0.96      1.00      0.98       888
#
#     accuracy                           0.98      1776
#    macro avg       0.98      0.98      0.98      1776
# weighted avg       0.98      0.98      0.98      1776

# %%
prob_true, prob_pred = calibration_curve(
    y_true,
    y_pred_prob[:,1],
    n_bins=10
)

plt.figure(figsize=(7,6))

plt.plot(
    prob_pred,
    prob_true,
    marker='o'
)

plt.plot(
    [0,1],
    [0,1],
    linestyle='--'
)

plt.xlabel("Predicted Probability")
plt.ylabel("Observed Frequency")
plt.title("Calibration Curve")

plt.show()
